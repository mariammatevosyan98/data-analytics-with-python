# %% [markdown]
# ## Data Types

# %% [markdown]
# ### integer

# %%
x = 42
x
# Out:
# 42

# %%
y = '34'

# %%
x = y

# %%
x = y

# %%
type(x)
# Out:
# str

# %% [markdown]
# ### Float

# %%
x = 5
x = 4.1
x
# Out:
# 4.1

# %%
type(x)
# Out:
# float

# %%
a = 5
b = 4.1
c = 2.9 
a + b + c
# Out:
# 12.0

# %%
d = a + b + c

# %%
type(d)
# Out:
# float

# %%
a = 5
b = 2
div1 = a/b
div2 = a//b

# %%
type(div)
# Out:
# float

# %%
print(f"simple division: {div1}")
print(f"simple division: {div2}")
# Out:
# simple division: 2.5
# simple division: 2

# %% [markdown]
# ### String

# %%
first_name = "Karen"
last_name = "Hovhannisyan"

# %%
type(first_name)
# Out:
# str
