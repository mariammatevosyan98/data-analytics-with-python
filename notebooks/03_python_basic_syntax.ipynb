# %% [markdown]
# # Session 02

# %% [markdown]
# ### Arithmetic Operations

# %%
r = 1500
t = 0.2

total = r * (1 + t)
total
# Out:
# 1800.0

# %%
2!=5
# Out:
# True

# %% [markdown]
# and   or  not

# %%
(10>5) and  (10<5)
# Out:
# False

# %% [markdown]
# ## Basic Data Structures

# %% [markdown]
# ### List

# %%
sales = [100, 200, 150, 200]
sales
# Out:
# [100, 200, 150, 200]

# %%
sales[-1]
# Out:
# 200

# %% [markdown]
# ## Analytical context

# %% [markdown]
# ### Tuple

# %%
coordinates = (40.18, 44.51)
coordinates
# Out:
# (40.18, 44.51)

# %% [markdown]
# ## Dictionary

# %%
customers = {
            "Alice": 30,
            "Bob": 25,
            "Charlie": 35,
            }
# Out:
#   Cell In[4], line 5
#     "Charlie" 40
#             ^
# SyntaxError: ':' expected after dictionary key

# %%
customers
# Out:
# {'Alice': 30, 'Bob': 25, 'Charlie': 35}

# %%
import pandas as pd

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie","Narek","Arpine"],   
    "Age": [30, 25, 35, 30, 28],
    "City": ["New York", "Los Angeles", "Chicago", "Boston","San Francisco"]
}

# %%
data["Name"]
data["Age"]
# Out:
# [30, 25, 35, 30, 28]

# %%
df=pd.DataFrame(data)

# %%
df.head()
# Out:
#       Name  Age           City
# 0    Alice   30       New York
# 1      Bob   25    Los Angeles
# 2  Charlie   35        Chicago
# 3    Narek   30         Boston
# 4   Arpine   28  San Francisco

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      str
#  1   Age     5 non-null      int64
#  2   City    5 non-null      str
# dtypes: int64(1), str(2)
# memory usage: 252.0 bytes

# %%
df.shape
# Out:
# (5, 3)

# %%
list(df.columns)
# Out:
# ['Name', 'Age', 'City']

# %%
df.head()
# Out:
#       Name  Age           City
# 0    Alice   30       New York
# 1      Bob   25    Los Angeles
# 2  Charlie   35        Chicago
# 3    Narek   30         Boston
# 4   Arpine   28  San Francisco

# %%
df[["Name", "Age"]]
# Out:
#       Name  Age
# 0    Alice   30
# 1      Bob   25
# 2  Charlie   35
# 3    Narek   30
# 4   Arpine   28

# %%
df["State"] = "Unknown"

# %%
df.head()
# Out:
#       Name  Age           City    State
# 0    Alice   30       New York  Unknown
# 1      Bob   25    Los Angeles  Unknown
# 2  Charlie   35        Chicago  Unknown
# 3    Narek   30         Boston  Unknown
# 4   Arpine   28  San Francisco  Unknown

# %%
df["Age"] = df["Age"] * 0.9

# %%
df.head()
# Out:
#       Name   Age           City    State
# 0    Alice  27.0       New York  Unknown
# 1      Bob  22.5    Los Angeles  Unknown
# 2  Charlie  31.5        Chicago  Unknown
# 3    Narek  27.0         Boston  Unknown
# 4   Arpine  25.2  San Francisco  Unknown
