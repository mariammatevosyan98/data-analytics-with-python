# %% [markdown]
# ## Homework

# %% [markdown]
# ### Part 1

# %%
import pandas as pd

# %%
data = {
    "revenues": [120, 250, 80, 310, 95],
    "tax_rate": 0.18,
    "discount_rate": 0.10
    }

# %%
r = revenues

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#    revenues  tax_rate  discount_rate
# 0       120      0.18            0.1
# 1       250      0.18            0.1
# 2        80      0.18            0.1
# 3       310      0.18            0.1
# 4        95      0.18            0.1

# %%
df['revenues_with_tax'] = df['revenues'] * (1 + df['tax_rate'])
df['revenues_with_tax']
# Out:
# 0    141.6
# 1    295.0
# 2     94.4
# 3    365.8
# 4    112.1
# Name: revenues_with_tax, dtype: float64

# %%
df['final_revenues'] = df['revenues_with_tax'] * (1 - df['discount_rate'])
df['final_revenues']
# Out:
# 0    127.44
# 1    265.50
# 2     84.96
# 3    329.22
# 4    100.89
# Name: final_revenues, dtype: float64

# %%
df['greater_100'] = df['revenues'] > 100

df['greater_100']
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# Name: greater_100, dtype: bool

# %%
df['between_100_300'] = (df['revenues'] > 100) & (df['revenues'] < 300)
df['between_100_300']
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# Name: between_100_300, dtype: bool

# %% [markdown]
# If we don't put the parentheses, the calculation result will be incorrect.

# %% [markdown]
# ### Part 2

# %%
sales = [120, 250, 80, 310, 95]

# %% [markdown]
# ### Part 4

# %%
customer_ids = [1, 2, 3, 3, 4, 5, 5, 6]

# %%
customer_set = set(customer_ids)    
customer_set
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
customer_ids
# Out:
# [1, 2, 3, 3, 4, 5, 5, 6]

# %%
len(customer_ids)
# Out:
# 8

# %%
len(customer_set)
# Out:
# 6
